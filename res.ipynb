# %%
class Restaurant:
    def __init__(self):
        self.admin_login= False
        self.user_login=False
        self.admin_details={}
        self.foods={}
        self.user_details={}
        self.order_history=[] 
        
    def Register_Admin(self):
        self.admin_name= input("Enter your name :")
        a=int(input("Enter your mobile number :"))
        if len(str(a))==10:
            self.admin_number=a
        else:
            print("\n Mobile number should be 10 digits ")
        
        self.admin_mail= input("\n Enter your Mail_Id ")
        self.admin_pass= input("\n Create a strong password ")
        d={}
        d["admin_name"]= self.admin_name
        d["admin_mail"]= self.admin_mail
        d["admin_number"]= self.admin_number
        d["admin_pass"]= self.admin_pass
        self.admin_details[self.admin_number]=d
        print("\n Your registration sucessfully completed ")
        
    def Login_Admin(self):
        num= int(input("Enter your number "))
        if num in self.admin_details:
            z= input("\n Enter your password ")
            if self.admin_details[num]["admin_pass"]== z:
                self.admin_login= True
                print("\n Loggin sucessful")
                
                
        else:
            print("\n Register first or enter valid number")
            
    def Add_New_Food(self):
        self.food=[]
        self.food_id= input("\n Create Food_ID:")
        n= input("\n Enter food name: ")
        self.food.append(n)
        q= int(input("\n Enter the quantity in pieces: "))
        self.food.append(q)
        p= int(input("\n Enter the price: "))
        self.food.append(p)
        self.foods[self.food_id]= self.food
        print("\n Food item added sucessfully")
        print(self.foods)
            
       
          
       
        
    def Discount(self):
        t=input("\n 10% discount available on every order plz hurry \n Enter y or Y to available this offer")
        if t== "y" or "Y":
            self.food[2]= self.food[2] - self.food[2]//10
            print("\n Discount applied,Now order quickly  ")
        
        
    def Stock(self):
        print(" \n  Total no.of food items you have : ",len(list(self.foods.keys())))
        k=1
        for i in self.foods:
            print("\n The followings are the list,Which are current availible here and its details... ")
            print("S.no-",k,"\n")                 
            print("  Food_ID         : ",i)
            print("  Food_Name       : ",self.foods[i][0])
            print("  Food_Quantity   : ",self.foods[i][1])
            print("  Food_Price      : ",self.foods[i][2])
            k+=1
            
    def Edit_Food(self):
        t= input("\n Enter your Food_ID: ")
        if t in self.foods:
            j=int(input("\n 1 To change Food_ID \n 2 To change Food_Name  \n 3 To change Food_Quantity \n 4 To change Food_Price"))
            if j==1:
                b=self.foods[t]
                self.foods.pop(t)
                c=input(" \n Enter new Food_Id: ")
                self.foods[c]=b
                print(" \n  Your Food_Id has been changed sucessfully ")
            if j==2:
                self.foods[t][0]=input("Enter new name to food:")
                print(" \n  Your Food_Name has been changed sucessfully ")
            if j==3:
                self.foods[t][1]=int(input("Enter new quantity of the food:"))
                print("\n Food_Quantity has been changed sucessfully")
            if j==4:
                self.foods[t][2]=int(input("Enter new price: "))
                print("\n Price has been changed sucessfully ")
                
        else:
            print("\n Invalid Food_ID ")
            
    def List_Of_Food_Items(self):
        print("Available food list is this : \n ",self.foods.values())
        
    
    
    def Remove_Food(self):
        d=input(" \n Enter your food_id:")
        if d in self.foods:
            p=input(" \n  Do you want to remove this itemfor the list... if Yes enter Y or y, if not enter N or n:")
            if p=="Y" or "y":
                self.foods.pop(d)
                print(" \n List was updated, After removing that item:")
            if p=="N" or "n":
                    pass
        else:
            
            print(" \n Food_Id was not found ")
            
            

        
    def User_Register(self):
        print("Give us your details for registration")
        self.user_name= input("\n Enter your full name: ")
        a=int(input("\n Enter your mobile number: "))
        if len(str(a))==10:
            self.user_number=a
        else:
            print("\n Please enter valid number, should have 10 digits")
        
        self.user_mail= input("\n Enter your Mail_Id: ")
        self.user_pass= input("\n Enter your password: ")
        self.user_place= input("\n Enter your place: ")
        s={}
        s["user_name"]= self.user_name
        s["user_mail"]= self.user_mail
        s["user_number"]= self.user_number
        s["user_pass"]= self.user_pass
        s["user_place"]= self.user_place
        self.user_details[self.user_number]=s
        print("\n Your registration sucessfully completed...Thanks ")
        
    def Login_User(self):
    
        num= int(input("Enter your number: "))
        if num in self.user_details:
            n= input("\n Enter your password:")
            if self.user_details[num]["user_pass"]== n:
                self.user_login= True
                print("\n Login sucessful")
                n= int(input("\n 1 Place new order  \n 2 Order history  \n 3 Update profile "))
                if n==1:
                    print("\n List of all food items with name, quantity & price \n " ,list(self.foods.values()))
                    print("\n Order the food by entering the Food_Id \n ", self.foods)
                    t= input("\n Enter your Food_Id:")
                    if t in self.foods:
                        r= input("\n Confirm with y or Y to place the order:")
                        if r=="y" or "Y":
                            g=self.foods.pop(t)
                            
                            self.order_history.append(g)
                            print("\n Order place succesfully ")
                    else:
                        print("\n Food_Id not found ")
                        
                if n==2:
                    print("\n Order details are saved in this list ", self.order_history)
                    
                if n==3:
                    x= int(input("\n Enter your number: "))
                    if x in self.user_details:
                        e= list(self.user_details.values())[0]
                        z= int(input(" \n 1 To change Name \n 2 To change Mail_Id \n 3 To change Number \n 4 To change password \n 5 To change place "))
                        if z==1:
                            e["user_name"]= input("\n Enter new user Name: ")
                            print("\n Profile updated sucessfully ", self.user_details)
                    
                        elif z==2:
                            e["user_name"]= input("\n Enter new Mail_Id: ")
                            print("\n Profile updated sucessfully ", self.user_details)
                    
                        elif z==3:
                            e["user_number"]=int(input("\n Enter new number: "))
                            print("\n Profile updated sucessfully ", self.user_details)
                     
                        elif z==4:
                            e["user_pass"]= input("\n Enter new password: ")
                            print("\n Profile updated sucessfully ", self.user_details)
                     
                        elif z==5:
                            e["user_address"]= input("\n Enter present place: ")
                            print("\n Profile updated sucessfully ", self.user_details)
                            
                    else:
                        print("Please check the number you enter")
                     
                            
                      
                    
                            
                
                   
            
            
                
                
        else:
            print("\n Register first or enter valid number")
                      
    
    
    def Menu(self):
        m= True
        while m:
            u= int(input("\n 1 To register admin \n 2 To login admin \n 3 To add new food item \n 4 To see discount \n 5 To see current stock \n 6 To edit food \n 7 To see list of food items \n 8 To remove food \n 9 To user register \n 10 To user login \n 11 exit"))
            if u==1:
                self.Register_Admin()
            if u==2:
                self.Login_Admin()
            if u==3:
                self.Add_New_Food()
            if u==4:
                self.Discount()
            if u==5:
                self.Stock()
            if u==6:
                self.Edit_Food()
            if u==7:
                self.List_Of_Food_Items()
            if u==8:
                self.Remove_Food()
            if u==9:
                self.User_Register()
            if u==10:
                self.Login_User()
        else:
            print("Please enter given input ")
